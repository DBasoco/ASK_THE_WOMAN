# %% [markdown]
# ## This was the most authentic way for me to ask you out! Run in order ;)

# %%
def sliding_into_DMs():
    
    answer = input("Will you go on a date with me? Yes or No ")
    
    
    if answer == "Yes":
        
        print("Psychedelic")
        
        available = input("When are you free? This week, 1. Next week, 2. Three weeks, 3. Next month, 4. Longer, 5")
        
        if available == "1":
            
            print("That's so soon, great!")
            
            print("I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.")
            
            date = input("Which would you prefer? Video chat or In person")
            
            if date == "Video chat":
                
                print("Ohhhhh, my camera has never been graced with such beauty before!")
                
                print("Message me back, ",answer, available, date)
                
            else:
                
                print("Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.")
                
                print("Message me back, ",answer, available, date)
                
            
        elif available == "2":
            
            print("Exciting! I'm looking forward to it.")
        
            print("I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.")
            
            date = input("Which would you prefer? Video chat or In person")
            
            if date == "Video chat":
                
                print("Ohhhhh, my camera has never been graced with such beauty before!")
                
                print("Message me back, ",answer, available, date)
                
            else:
                
                print("Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.")
                
                print("Message me back, ",answer, available, date)
        
        elif available == "3":
            
            print("To be expected, you are Lexie Rae after all!")
        
            print("I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.")
            
            date = input("Which would you prefer? Video chat or In person")
            
            if date == "Video chat":
                
                print("Ohhhhh, my camera has never been graced with such beauty before!")
                
                print("Message me back, ",answer, available, date)
                
            else:
                
                print("Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.")
                
                print("Message me back, ",answer, available, date)
        
        elif available == "4":
            
            print("It's a drop in the ocean.")
        
            print("I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.")
            
            date = input("Which would you prefer? Video chat or In person")
            
            if date == "Video chat":
                
                print("Ohhhhh, my camera has never been graced with such beauty before!")
                
                print("Message me back, ",answer, available, date)
                
            else:
                
                print("Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.")
                
                print("Message me back, ",answer, available, date)
            
        else:
            
            print("Wowza, but hey you're being the boss now so no worries.")
        
            print("I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.")
            
            date = input("Which would you prefer? Video chat or In person")
            
            if date == "Video chat":
                
                print("Ohhhhh, my camera has never been graced with such beauty before!")
                
                print("Message me back, ",answer, available, date)
                
            else:
                
                print("Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.")
                
                print("Message me back, ",answer, available, date)
        
    else:
        
        print("No issue have a great day! Please message me back ", answer)

# %%
sliding_into_DMs()
# Out:
# Will you go on a date with me? Yes or No Yes
# Psychedelic
# When are you free? This week, 1. Next week, 2. Three weeks, 3. Next month, 4. Longer, 52
# Exciting! I'm looking forward to it.
# I was thinking, given the quarantine, we could have a simple dinner over video chat. Wherein, we cook the same thing and have a nice face-to-face conversation. Or we have dinner in person at one of our places.
# Which would you prefer? Video chat or In personIn person
# Can't wait to talk in person. Now I need to have a fashion show to pick the best outfit.
# Message me back,  Yes 2 In person
